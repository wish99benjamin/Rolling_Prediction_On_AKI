# %% [markdown]
# # 前置設定

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# import argparse
from torch.utils.data import DataLoader

from drive.MyDrive.iirlab.topic.LSAN.LSANori.trainer import *
from drive.MyDrive.iirlab.topic.LSAN.LSANori.transformer import *
from drive.MyDrive.iirlab.topic.LSAN.LSANori.dataset import *
from drive.MyDrive.iirlab.topic.LSAN.LSANori.LSAN import *

import pickle

# %%
time_interval = '12_with_gap_6/18_39'
with open('/content/drive/MyDrive/iirlab/topic/trimmed_pickle/' + time_interval + '/final_train.pickle','rb') as f:
  train_data = pickle.load(f)
  train_visit = train_data[0]
  train_label = train_data[1]
  train_value = train_data[3]
  train_dataset = Dataset(train_visit, train_label, train_value)
  

with open('/content/drive/MyDrive/iirlab/topic/trimmed_pickle/' + time_interval + '/final_val.pickle','rb') as f:
  validate_data = pickle.load(f)
  validate_visit = validate_data[0]
  validate_label = validate_data[1]
  validate_value = validate_data[3]
  validate_dataset = Dataset(validate_visit, validate_label, validate_value)
  

with open('/content/drive/MyDrive/iirlab/topic/trimmed_pickle/' + time_interval + '/final_test.pickle','rb') as f:
  test_data = pickle.load(f)
  test_visit = test_data[0]
  test_label = test_data[1]
  test_value = test_data[3]
  test_dataset = Dataset(test_visit, test_label, test_value)

# %% [markdown]
# # 參數

# %%
output_path = '/content/drive/MyDrive/iirlab/topic/LSAN/LSANori/output/result.txt'
hidden = 256 
layers = 8
attn_heads = 8 
dropout = 0.1
batch_size = 32
epochs = 12
num_workers = 2
with_cuda = 1
lr = 0.0001
adam_weight_decay = 0.01 ###
adam_beta1 = 0.9
adam_beta2 = 0.999
saving_path = '/content/drive/MyDrive/iirlab/topic/LSAN/LSANori/model_parameters/models.pth'

# %%
def process():
  # print("Creating Dataloader")
  train_data_loader = DataLoader(train_dataset, batch_size=batch_size, num_workers=num_workers, collate_fn=train_dataset.collate_fn,shuffle=False)
  validate_data_loader = DataLoader(validate_dataset, batch_size=batch_size, num_workers=num_workers, collate_fn=test_dataset.collate_fn,shuffle=False)
  test_data_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=num_workers, collate_fn=test_dataset.collate_fn,shuffle=False)




  embedding_dim = hidden
  code2idx_file = '/content/drive/MyDrive/iirlab/topic/LSAN/LSANori/code2idx_new.pickle'



  with open(code2idx_file, 'rb') as f:
      code2idx = pickle.load(f)
      #  list out keys and values separately
      diagnosis_code_list = list(code2idx.keys())
      dignosis_index_list = list(code2idx.values())
      # print(len(dignosis_index_list))

  # model = LSAN(len(dignosis_index_list), embedding_dim, transformer_hidden = hidden, attn_heads = attn_heads,
  #                     transformer_dropout = dropout, transformer_layers = layers)
  model = LSAN(51, embedding_dim, transformer_hidden = hidden, attn_heads = attn_heads,
                      transformer_dropout = dropout, transformer_layers = layers)

  # defining trainer
  LSAN_train = LSAN_trainer(model, train_dataloader=train_data_loader, validate_dataloader=validate_data_loader, test_dataloader=test_data_loader, with_cuda=with_cuda, lr=lr, output_dir=output_path)

  # training process
  for epoch in range(epochs):
      model.train()
      LSAN_train.train(epoch)
  
      # Validation
      if validate_data_loader is not None:
          model.eval()
          LSAN_train.validate(epoch)
        
  torch.save(model.state_dict(), saving_path)

  # Test after the end of training
  # test_model = LSAN(len(dignosis_index_list), embedding_dim, transformer_hidden = hidden, attn_heads = attn_heads, transformer_dropout = dropout, transformer_layers = layers) 
  test_model = LSAN(51, embedding_dim, transformer_hidden = hidden, attn_heads = attn_heads, transformer_dropout = dropout, transformer_layers = layers) 


  test_model.load_state_dict(torch.load(saving_path))
  test_model.eval()

  LSAN_test = LSAN_trainer(test_model, train_dataloader=train_data_loader, validate_dataloader=validate_data_loader, test_dataloader=test_data_loader, with_cuda=with_cuda, lr=lr, output_dir=output_path)

  test_loss = LSAN_test.test(epoch, False)
  return model, test_loss

# %% [markdown]
# # 暫定版

# %%
for num in range(20):
  model, loss = process()
  loss = round(loss, 3) * 100
  saving_path = '/content/drive/MyDrive/iirlab/topic/LSAN/LSANori/model_parameters/' + str(num) + '_' + str(loss) + '_models.pth'
  torch.save(model.state_dict(), saving_path)
# Out:
# Done for epoch 0
# 0.7762383983916595
# Validation epoch:0 auc:0.7661040770026357 precision:0.7735849056603774 recall:0.9288025889967637
# Validation loss : 0.5312646941134804
# Done for epoch 1
# 0.596820535028682
# Validation epoch:1 auc:0.7871723439984876 precision:0.7977044476327116 recall:0.8996763754045307
# Validation loss : 0.5126597415982631
# Done for epoch 2
# 0.578893859095934
# Validation epoch:2 auc:0.8018146887754535 precision:0.7972779369627507 recall:0.9004854368932039
# Validation loss : 0.4966082907559579
# Done for epoch 3
# 0.5650881209543773
# Validation epoch:3 auc:0.8089780802722448 precision:0.8048069919883467 recall:0.8940129449838188
# Validation loss : 0.4899330034590604
# Done for epoch 4
# 0.5562887409654986
# Validation epoch:4 auc:0.8166363616143417 precision:0.8076358296622613 recall:0.889967637540453
# Validation loss : 0.4830516953217356
# Done for epoch 5
# 0.5470481268247637
# Validation epoch:5 auc:0.8208276337592721 precision:0.8101545253863135 recall:0.8907766990291263
# Validation loss : 0.4772856172762419
# Done for epoch 6
# 0.5382052881627524
# Validation epoch:6 auc:0.8257605456021531 precision:0.8122238586156112 recall:0.8923948220064725
# Validation loss : 0.4722357868102559
# Done for epoch 7
# 0.5281795428580597
# Validation epoch:7 auc:0.8272556411881805 precision:0.8220532319391635 recall:0.8745954692556634
# Validation loss : 0.47356997038188736
# Done for epoch 8
# 0.5235939668256695
# Validation epoch:8 auc:0.8278575718146332 precision:0.819213313161876 recall:0.8762135922330098
# Validation loss : 0.4708728528859323
# Done for epoch 9
# 0.5173679452483394
# Validation epoch:9 auc:0.829040580967315 precision:0.8279906176700548 recall:0.8567961165048543
# Validation loss : 0.4710421865446526
# Done for epoch 10
# 0.516106472546313
# Validation epoch:10 auc:0.8292303350793491 precision:0.8248456790123457 recall:0.8648867313915858
# Validation loss : 0.46805334614034283
# Done for epoch 11
# 0.5112461592970776
# Validation epoch:11 auc:0.8299678043572549 precision:0.8236641221374046 recall:0.8729773462783171
# Validation loss : 0.46606103997481496
# Testing epoch:11 auc:0.7905736275041129 precision:0.7858787413660783 recall:0.8345558272208639 F1:0.8094861660079051
# Testing loss : 0.5158745411195254
# Done for epoch 0
# 0.7821914836639116
# Validation epoch:0 auc:0.69781622905059 precision:0.6802646085997794 recall:0.9983818770226537
# Validation loss : 0.595320255087133
# Done for epoch 1
# 0.6188627215994507
# Validation epoch:1 auc:0.7858864644847029 precision:0.8017686072218129 recall:0.8802588996763754
# Validation loss : 0.5386250149785426
# Done for epoch 2
# 0.5824223729241796
# Validation epoch:2 auc:0.7984185767190473 precision:0.8017492711370262 recall:0.889967637540453
# Validation loss : 0.506296865249935
# Done for epoch 3
# 0.5666182202701809
# Validation epoch:3 auc:0.8086041326082363 precision:0.8029411764705883 recall:0.883495145631068
# Validation loss : 0.49551869222992345
# Done for epoch 4
# 0.5564269805405321
# Validation epoch:4 auc:0.8169241205974266 precision:0.8118081180811808 recall:0.889967637540453
# Validation loss : 0.4845907411031556
# Done for epoch 5
# 0.5449080603713748
# Validation epoch:5 auc:0.8193749374436993 precision:0.8074127906976745 recall:0.8988673139158576
# Validation loss : 0.4749009410540263
# Done for epoch 6
# 0.5371612054961068
# Validation epoch:6 auc:0.8220036922118796 precision:0.816160118606375 recall:0.8907766990291263
# Validation loss : 0.47299166468151826
# Done for epoch 7
# 0.5309717532466439
# Validation epoch:7 auc:0.8233841012466776 precision:0.8196969696969697 recall:0.8754045307443366
# Validation loss : 0.4732972524668041
# Done for epoch 8
# 0.5294839220137155
# Validation epoch:8 auc:0.8229712296622517 precision:0.8203957382039574 recall:0.872168284789644
# Validation loss : 0.47229574908289995
# Done for epoch 9
# 0.5224650629929134
# Validation epoch:9 auc:0.8245671103993595 precision:0.8205521472392638 recall:0.8656957928802589
# Validation loss : 0.47260565977347524
# Done for epoch 10
# 0.5232472671430652
# Validation epoch:10 auc:0.826354830458524 precision:0.8203363914373089 recall:0.8681229773462783
# Validation loss : 0.47184917278457106
# Done for epoch 11
# 0.5160235284256334
# Validation epoch:11 auc:0.8261129460959307 precision:0.8213457076566125 recall:0.8592233009708737
# Validation loss : 0.4715794821580251
# Testing epoch:11 auc:0.7969184604161581 precision:0.8012422360248447 recall:0.8410757946210269 F1:0.8206759443339959
# Testing loss : 0.5067287453433924
# Done for epoch 0
# 50.0
# Validation epoch:0 auc:0.5 precision:0.6798679867986799 recall:1.0
# Validation loss : 32.03441298635382
# Done for epoch 1
# 50.0
# Validation epoch:1 auc:0.5 precision:0.6798679867986799 recall:1.0
# Validation loss : 32.03441298635382
# Done for epoch 2
# 50.0
# Validation epoch:2 auc:0.5 precision:0.6798679867986799 recall:1.0
# Validation loss : 32.03441298635382
# Done for epoch 3
# 50.0
# Validation epoch:3 auc:0.5 precision:0.6798679867986799 recall:1.0
# Validation loss : 32.03441298635382
# Done for epoch 4
# 50.0
# Validation epoch:4 auc:0.5 precision:0.6798679867986799 recall:1.0
# Validation loss : 32.03441298635382
# Done for epoch 5
# 50.0
# Validation epoch:5 auc:0.5 precision:0.6798679867986799 recall:1.0
# Validation loss : 32.03441298635382
# Done for epoch 6
# 50.0
# Validation epoch:6 auc:0.5 precision:0.6798679867986799 recall:1.0
# Validation loss : 32.03441298635382
# Done for epoch 7
# 50.0
# Validation epoch:7 auc:0.5 precision:0.6798679867986799 recall:1.0
# Validation loss : 32.03441298635382
# Done for epoch 8
# 50.0
# Validation epoch:8 auc:0.5 precision:0.6798679867986799 recall:1.0
# Validation loss : 32.03441298635382
# Done for epoch 9
# 50.0
# Validation epoch:9 auc:0.5 precision:0.6798679867986799 recall:1.0
# Validation loss : 32.03441298635382
# Done for epoch 10
# 50.0
# Validation epoch:10 auc:0.5 precision:0.6798679867986799 recall:1.0
# Validation loss : 32.03441298635382
# Done for epoch 11
# 50.0
# Validation epoch:11 auc:0.5 precision:0.6798679867986799 recall:1.0
# Validation loss : 32.03441298635382
# Testing epoch:11 auc:0.5 precision:0.6749174917491749 recall:1.0 F1:0.8059113300492611
# Testing loss : 32.50253038239061
# Done for epoch 0
# 0.7046283065270977
# Validation epoch:0 auc:0.7776929792368686 precision:0.7966226138032305 recall:0.877831715210356
# Validation loss : 0.5205731308251097
# Done for epoch 1
# 0.5813811683103818
# Validation epoch:1 auc:0.796072020373892 precision:0.8051660516605166 recall:0.8826860841423948
# Validation loss : 0.5027904123590704
# Done for epoch 2
# 0.5637387066077786
# Validation epoch:2 auc:0.8089683492921407 precision:0.8052516411378556 recall:0.8932038834951457
# Validation loss : 0.4895917741875899
# Done for epoch 3
# 0.5554989702811762
# Validation epoch:3 auc:0.8152281497792457 precision:0.8062865497076024 recall:0.8923948220064725
# Validation loss : 0.48492203365292463
# Done for epoch 4
# 0.5476401512111936
# Validation epoch:4 auc:0.8176108497647884 precision:0.8106508875739645 recall:0.8867313915857605
# Validation loss : 0.4824537556422384
# Done for epoch 5
# 0.5411179619176048
# Validation epoch:5 auc:0.8191858784016726 precision:0.8120854826823877 recall:0.8915857605177994
# Validation loss : 0.47724115953110813
# Done for epoch 6
# 0.5358297283909902
# Validation epoch:6 auc:0.8201381243118806 precision:0.815033161385409 recall:0.8948220064724919
# Validation loss : 0.4749333539552856
# Done for epoch 7
# 0.5307127452698075
# Validation epoch:7 auc:0.8220592978124757 precision:0.8160237388724035 recall:0.889967637540453
# Validation loss : 0.4745967487494151
# Done for epoch 8
# 0.5283995094169088
# Validation epoch:8 auc:0.8227057129194053 precision:0.8188567186340014 recall:0.8923948220064725
# Validation loss : 0.4721040375400008
# Done for epoch 9
# 0.5214998998812267
# Validation epoch:9 auc:0.8242612795960809 precision:0.8258859784283513 recall:0.8673139158576052
# Validation loss : 0.47386681249267176
# Done for epoch 10
# 0.5196828584210211
# Validation epoch:10 auc:0.8248409679822952 precision:0.8150633855331841 recall:0.8843042071197411
# Validation loss : 0.469391359571825
# Done for epoch 11
# 0.5170596886833175
# Validation epoch:11 auc:0.8252607902667957 precision:0.8176382660687593 recall:0.8851132686084142
# Validation loss : 0.4718380722037533
# Testing epoch:11 auc:0.7824788287226077 precision:0.784627092846271 recall:0.8402607986960066 F1:0.811491538764266
# Testing loss : 0.5227417281845159
# Done for epoch 0
# 0.6291879175089988
# Validation epoch:0 auc:0.798620147021208 precision:0.8020527859237536 recall:0.8851132686084142
# Validation loss : 0.5024539054485789
# Done for epoch 1
# 0.5660756409418684
# Validation epoch:1 auc:0.8198322935086022 precision:0.8137254901960784 recall:0.8729773462783171
# Validation loss : 0.48905086674188314
# Done for epoch 2
# 0.5459375118508059
# Validation epoch:2 auc:0.8255805224702231 precision:0.8183194549583649 recall:0.8745954692556634
# Validation loss : 0.4761078964199936
# Done for epoch 3
# 0.5331652612746263
# Validation epoch:3 auc:0.827304296088702 precision:0.8258513931888545 recall:0.8632686084142395
# Validation loss : 0.47449566554604916
# Done for epoch 4
# 0.5226698854640752
# Validation epoch:4 auc:0.827888154894961 precision:0.8242097147262915 recall:0.8648867313915858
# Validation loss : 0.4709482747211791
# Done for epoch 5
# 0.5190907711742305
# Validation epoch:5 auc:0.8276824141727553 precision:0.8224442736356649 recall:0.8656957928802589
# Validation loss : 0.46937392730461924
# Done for epoch 6
# 0.508561383901524
# Validation epoch:6 auc:0.827447480510237 precision:0.8233908948194663 recall:0.848705501618123
# Validation loss : 0.4725875577382874
# Done for epoch 7
# 0.5039572301281601
# Validation epoch:7 auc:0.8267218274224581 precision:0.8258115597783057 recall:0.8438511326860841
# Validation loss : 0.47463412452162357
# Done for epoch 8
# 0.49935714574922035
# Validation epoch:8 auc:0.8265981049611317 precision:0.8266351457840819 recall:0.848705501618123
# Validation loss : 0.47506671882512275
# Done for epoch 9
# 0.4946029087325104
# Validation epoch:9 auc:0.8249772017037555 precision:0.8323932312651088 recall:0.8357605177993528
# Validation loss : 0.48015849056996796
# Done for epoch 10
# 0.4888899963693458
# Validation epoch:10 auc:0.823349347746305 precision:0.833063209076175 recall:0.8317152103559871
# Validation loss : 0.4826670137413761
# Done for epoch 11
# 0.48488709944136005
# Validation epoch:11 auc:0.8207574316885197 precision:0.8294820717131474 recall:0.8422330097087378
# Validation loss : 0.4840884836096513
# Testing epoch:11 auc:0.7906274089610938 precision:0.8102734051367025 recall:0.7970660146699267 F1:0.8036154478225144
# Testing loss : 0.523795288382915
# Done for epoch 0
# 3.7442839644035373
# Validation epoch:0 auc:0.5637608569935164 precision:0.6798679867986799 recall:1.0
# Validation loss : 0.6797135723264593
# Done for epoch 1
# 0.6972795118804739
# Validation epoch:1 auc:0.5965459191049722 precision:0.6798679867986799 recall:1.0
# Validation loss : 0.6728785665411698
# Done for epoch 2
# 0.6963137894117531
# Validation epoch:2 auc:0.5425285534759061 precision:0.6798679867986799 recall:1.0
# Validation loss : 0.6735118449779979
# Done for epoch 3
# 0.6963247674352983
# Validation epoch:3 auc:0.5608749263225793 precision:0.6798679867986799 recall:1.0
# Validation loss : 0.6672721452880324
# Done for epoch 4
# 0.6959166654518673
# Validation epoch:4 auc:0.5850251337314695 precision:0.6798679867986799 recall:1.0
# Validation loss : 0.6668288613620558
# Done for epoch 5
# 0.6963703699973451
# Validation epoch:5 auc:0.5736259856092705 precision:0.6798679867986799 recall:1.0
# Validation loss : 0.6649280044070461
# Done for epoch 6
# 0.6956029932539002
# Validation epoch:6 auc:0.6453975244386614 precision:0.6798679867986799 recall:1.0
# Validation loss : 0.6663174263217992
# Done for epoch 7
# 0.6961286125563774
# Validation epoch:7 auc:0.5946866068350405 precision:0.6798679867986799 recall:1.0
# Validation loss : 0.6665247365048057
# Done for epoch 8
# 0.695364869943186
# Validation epoch:8 auc:0.5231041270476762 precision:0.6798679867986799 recall:1.0
# Validation loss : 0.6689991720935755
# Done for epoch 9
# 0.6951540675984711
# Validation epoch:9 auc:0.49812609125991175 precision:0.6798679867986799 recall:1.0
# Validation loss : 0.669525380720172
# Done for epoch 10
# 0.6952697980303725
# Validation epoch:10 auc:0.5817874976367621 precision:0.6798679867986799 recall:1.0
# Validation loss : 0.6696980417820445
# Done for epoch 11
# 0.6952340642945105
# Validation epoch:11 auc:0.5652309300592756 precision:0.6798679867986799 recall:1.0
# Validation loss : 0.6669404663537678
# Testing epoch:11 auc:0.5369202807116251 precision:0.6749174917491749 recall:1.0 F1:0.8059113300492611
# Testing loss : 0.6677118372498897
# Done for epoch 0
# 0.7466544601596704
# Validation epoch:0 auc:0.7749224301871684 precision:0.7934306569343066 recall:0.8794498381877023
# Validation loss : 0.5269188520155454
# Done for epoch 1
# 0.5842690015790843
# Validation epoch:1 auc:0.7963722906171109 precision:0.8001464128843339 recall:0.8843042071197411
# Validation loss : 0.5022478349376143
# Done for epoch 2
# 0.5713854222988882
# Validation epoch:2 auc:0.802618189704067 precision:0.8048961424332344 recall:0.877831715210356
# Validation loss : 0.4997457987383792
# Done for epoch 3
# 0.5628803486333174
# Validation epoch:3 auc:0.808702137479287 precision:0.8084947839046199 recall:0.877831715210356
# Validation loss : 0.4951986419527154
# Done for epoch 4
# 0.5568103324465391
# Validation epoch:4 auc:0.8130984552764156 precision:0.8096654275092937 recall:0.8810679611650486
# Validation loss : 0.492779075576548
# Done for epoch 5
# 0.5497669348446261
# Validation epoch:5 auc:0.8165710250336413 precision:0.8106508875739645 recall:0.8867313915857605
# Validation loss : 0.48447447858358683
# Done for epoch 6
# 0.5441723926728513
# Validation epoch:6 auc:0.8186729167361736 precision:0.8130142109199701 recall:0.8794498381877023
# Validation loss : 0.48129760173329134
# Done for epoch 7
# 0.5371135810092718
# Validation epoch:7 auc:0.8206914000378118 precision:0.8165413533834587 recall:0.8786407766990292
# Validation loss : 0.47841972478649075
# Done for epoch 8
# 0.5326024382805624
# Validation epoch:8 auc:0.8212835996841601 precision:0.8142322097378277 recall:0.8794498381877023
# Validation loss : 0.47493945036018104
# Done for epoch 9
# 0.5269976891890293
# Validation epoch:9 auc:0.8223651286157541 precision:0.8197226502311248 recall:0.86084142394822
# Validation loss : 0.47515859677080524
# Done for epoch 10
# 0.5216346138916096
# Validation epoch:10 auc:0.8223943215560672 precision:0.8243034055727554 recall:0.8616504854368932
# Validation loss : 0.4761153114469428
# Done for epoch 11
# 0.5166794451094475
# Validation epoch:11 auc:0.8228558480410147 precision:0.8220015278838808 recall:0.8705501618122977
# Validation loss : 0.47348800092412713
# Testing epoch:11 auc:0.7877604436004892 precision:0.7925247902364607 recall:0.8467807660961695 F1:0.8187549251379038
# Testing loss : 0.517036786727738
# Done for epoch 0
# 0.658279003340657
# Validation epoch:0 auc:0.7888460725764299 precision:0.7978494623655914 recall:0.9004854368932039
# Validation loss : 0.5086050828297933
# Done for epoch 1
# 0.576953025174742
# Validation epoch:1 auc:0.7986952145820128 precision:0.8066914498141264 recall:0.877831715210356
# Validation loss : 0.4998165520659664
# Done for epoch 2
# 0.5662021578109565
# Validation epoch:2 auc:0.8065147521658381 precision:0.8093471810089021 recall:0.8826860841423948
# Validation loss : 0.4927220412513666
# Done for epoch 3
# 0.557030238899864
# Validation epoch:3 auc:0.8113371478775342 precision:0.8102678571428571 recall:0.8810679611650486
# Validation loss : 0.4880048956787377
# Done for epoch 4
# 0.5481356522616219
# Validation epoch:4 auc:0.8160094084676209 precision:0.8158682634730539 recall:0.8818770226537217
# Validation loss : 0.4820823157042788
# Done for epoch 5
# 0.5398679862753684
# Validation epoch:5 auc:0.8205676775764854 precision:0.8206106870229007 recall:0.8697411003236246
# Validation loss : 0.47918469393462465
# Done for epoch 6
# 0.5321984611639455
# Validation epoch:6 auc:0.8250286368843069 precision:0.8279654359780048 recall:0.8527508090614887
# Validation loss : 0.47510205287682383
# Done for epoch 7
# 0.5257472648840993
# Validation epoch:7 auc:0.8284567221610559 precision:0.8312101910828026 recall:0.8446601941747572
# Validation loss : 0.47272766263861404
# Done for epoch 8
# 0.5176162258917544
# Validation epoch:8 auc:0.8292880258899678 precision:0.8319805194805194 recall:0.8292880258899676
# Validation loss : 0.47259794044912906
# Done for epoch 9
# 0.512574759601545
# Validation epoch:9 auc:0.8302694647404886 precision:0.8403292181069959 recall:0.8260517799352751
# Validation loss : 0.47412373099410743
# Done for epoch 10
# 0.508424265169296
# Validation epoch:10 auc:0.8309659248879547 precision:0.8508098891730606 recall:0.8074433656957929
# Validation loss : 0.4771796266237895
# Done for epoch 11
# 0.5043658159610604
# Validation epoch:11 auc:0.8286582924632169 precision:0.8417564208782105 recall:0.8220064724919094
# Validation loss : 0.4741298728867581
# Testing epoch:11 auc:0.7941107925594044 precision:0.8260135135135135 recall:0.7970660146699267 F1:0.811281625881377
# Testing loss : 0.5196599332909835
# Done for epoch 0
# 0.7407083821897747
# Validation epoch:0 auc:0.7844177815589587 precision:0.7963768115942029 recall:0.88915857605178
# Validation loss : 0.5104220786638427
# Done for epoch 1
# 0.5762469992667687
# Validation epoch:1 auc:0.7979375882738908 precision:0.8027961736571008 recall:0.8826860841423948
# Validation loss : 0.49925542662018224
# Done for epoch 2
# 0.5652834175765014
# Validation epoch:2 auc:0.8067767935586472 precision:0.8046989720998532 recall:0.8867313915857605
# Validation loss : 0.4928285401118429
# Done for epoch 3
# 0.5553841053688225
# Validation epoch:3 auc:0.8119084954236591 precision:0.8096296296296296 recall:0.8843042071197411
# Validation loss : 0.4895992932612436
# Done for epoch 4
# 0.5469179309967185
# Validation epoch:4 auc:0.8158968071264139 precision:0.8127313101406366 recall:0.8883495145631068
# Validation loss : 0.48286762729025723
# Done for epoch 5
# 0.5398882779003191
# Validation epoch:5 auc:0.8187994194775299 precision:0.8173005219985086 recall:0.8867313915857605
# Validation loss : 0.4780457265544356
# Done for epoch 6
# 0.5342115678456651
# Validation epoch:6 auc:0.8216311346878857 precision:0.815592203898051 recall:0.8802588996763754
# Validation loss : 0.47728791466930454
# Done for epoch 7
# 0.5295633428237018
# Validation epoch:7 auc:0.8224554877167228 precision:0.821455938697318 recall:0.8673139158576052
# Validation loss : 0.47862436635452404
# Done for epoch 8
# 0.5232997768315948
# Validation epoch:8 auc:0.8253205662874366 precision:0.8255451713395638 recall:0.8576051779935275
# Validation loss : 0.47603345387860346
# Done for epoch 9
# 0.5206353390166739
# Validation epoch:9 auc:0.8245685005393744 precision:0.8221709006928406 recall:0.8640776699029126
# Validation loss : 0.47527971288614107
# Done for epoch 10
# 0.5155315374125954
# Validation epoch:10 auc:0.8248659905025634 precision:0.8306709265175719 recall:0.8414239482200647
# Validation loss : 0.47955357296425
# Done for epoch 11
# 0.5104811082617575
# Validation epoch:11 auc:0.8248284567221611 precision:0.8274231678486997 recall:0.8495145631067961
# Validation loss : 0.47424052890978363
# Testing epoch:11 auc:0.7844397833848396 precision:0.7977970102281668 recall:0.8264058679706602 F1:0.811849479583667
# Testing loss : 0.5229193568229675
# Done for epoch 0
# 0.6551847310126329
# Validation epoch:0 auc:0.7890309611984119 precision:0.7939262472885033 recall:0.8883495145631068
# Validation loss : 0.5084970948988932
# Done for epoch 1
# 0.5765760321827496
# Validation epoch:1 auc:0.7963097343164403 precision:0.8026315789473685 recall:0.8883495145631068
# Validation loss : 0.49821442051937703
# Done for epoch 2
# 0.5669415729636905
# Validation epoch:2 auc:0.8004113424304096 precision:0.8030634573304157 recall:0.8907766990291263
# Validation loss : 0.49736327874033076
# Done for epoch 3
# 0.5580131804742733
# Validation epoch:3 auc:0.806046274980816 precision:0.8017556693489393 recall:0.8867313915857605
# Validation loss : 0.49006882989615724
# Done for epoch 4
# 0.5488995154615209
# Validation epoch:4 auc:0.8109798818937043 precision:0.8095940959409594 recall:0.8875404530744336
# Validation loss : 0.48389016797668055
# Done for epoch 5
# 0.5415279718757677
# Validation epoch:5 auc:0.8137073366029427 precision:0.8145100972326104 recall:0.8810679611650486
# Validation loss : 0.4826984290491071
# Done for epoch 6
# 0.5347548546660849
# Validation epoch:6 auc:0.8157633536849832 precision:0.8093126385809313 recall:0.8859223300970874
# Validation loss : 0.47681643356356707
# Done for epoch 7
# 0.5302651664789986
# Validation epoch:7 auc:0.8160719647682915 precision:0.8174904942965779 recall:0.8697411003236246
# Validation loss : 0.47924531604114334
# Done for epoch 8
# 0.5267848923426717
# Validation epoch:8 auc:0.8178527341273811 precision:0.819213313161876 recall:0.8762135922330098
# Validation loss : 0.4774797323502992
# Done for epoch 9
# 0.5221170247101984
# Validation epoch:9 auc:0.8190746672004804 precision:0.8219814241486069 recall:0.8592233009708737
# Validation loss : 0.4774222326906104
# Done for epoch 10
# 0.5176257145504991
# Validation epoch:10 auc:0.819237313582224 precision:0.813161875945537 recall:0.8697411003236246
# Validation loss : 0.47576575634772317
# Done for epoch 11
# 0.5124363577415963
# Validation epoch:11 auc:0.8204828790355765 precision:0.8252730109204368 recall:0.8559870550161812
# Validation loss : 0.4762103505301894
# Testing epoch:11 auc:0.7848162535837067 precision:0.7950116913484022 recall:0.8312958435207825 F1:0.8127490039840638
# Testing loss : 0.5185541892260835
# Done for epoch 0
# 0.6909736467509711
# Validation epoch:0 auc:0.7815575684782972 precision:0.7950581395348837 recall:0.8851132686084142
# Validation loss : 0.5154526197073752
# Done for epoch 1
# 0.5825502404144832
# Validation epoch:1 auc:0.7952115237046675 precision:0.8049853372434017 recall:0.8883495145631068
# Validation loss : 0.5018272331932134
# Done for epoch 2
# 0.5693542790763518
# Validation epoch:2 auc:0.8036858172355119 precision:0.8082595870206489 recall:0.8867313915857605
# Validation loss : 0.4940619484374398
# Done for epoch 3
# 0.5609166818757018
# Validation epoch:3 auc:0.8105823018494422 precision:0.8058394160583942 recall:0.8932038834951457
# Validation loss : 0.48708225655974
# Done for epoch 4
# 0.5524970949197016
# Validation epoch:4 auc:0.8169491431176948 precision:0.8078889700511322 recall:0.8948220064724919
# Validation loss : 0.4809997468663935
# Done for epoch 5
# 0.5451466114330692
# Validation epoch:5 auc:0.8197405442676187 precision:0.8125925925925926 recall:0.8875404530744336
# Validation loss : 0.4778095703375967
# Done for epoch 6
# 0.5371979977152929
# Validation epoch:6 auc:0.823220064724919 precision:0.8153387937453462 recall:0.8859223300970874
# Validation loss : 0.4740105344538103
# Done for epoch 7
# 0.5321280154861322
# Validation epoch:7 auc:0.825597204150402 precision:0.8132440476190477 recall:0.8843042071197411
# Validation loss : 0.47024634375906826
# Done for epoch 8
# 0.5257229137570918
# Validation epoch:8 auc:0.8284525517410115 precision:0.8216995447647951 recall:0.8762135922330098
# Validation loss : 0.4681771167537622
# Done for epoch 9
# 0.519771375826427
# Validation epoch:9 auc:0.829525739832516 precision:0.8263565891472868 recall:0.8624595469255664
# Validation loss : 0.46842068852039803
# Done for epoch 10
# 0.5130882349585285
# Validation epoch:10 auc:0.8299872663174636 precision:0.8258164852255054 recall:0.8592233009708737
# Validation loss : 0.46810136657012136
# Done for epoch 11
# 0.5090472656889122
# Validation epoch:11 auc:0.8302652943204439 precision:0.8266978922716628 recall:0.8567961165048543
# Validation loss : 0.46762569849951224
# Testing epoch:11 auc:0.789536610692581 precision:0.8012718600953895 recall:0.8215158924205379 F1:0.8112676056338027
# Testing loss : 0.5208383620831004
# Done for epoch 0
# 0.7605237233288148
# Validation epoch:0 auc:0.7833501540275137 precision:0.7992565055762082 recall:0.8697411003236246
# Validation loss : 0.5199384846185383
# Done for epoch 1
# 0.5793298419032779
# Validation epoch:1 auc:0.79289833071987 precision:0.8007352941176471 recall:0.8810679611650486
# Validation loss : 0.5065820677238598
# Done for epoch 2
# 0.5692603683271328
# Validation epoch:2 auc:0.7969818670136455 precision:0.8020527859237536 recall:0.8851132686084142
# Validation loss : 0.5052234326538286
# Done for epoch 3
# 0.562989789022117
# Validation epoch:3 auc:0.8044066048332388 precision:0.8040786598689003 recall:0.8932038834951457
# Validation loss : 0.49828361785202696
# Done for epoch 4
# 0.5538745350947901
# Validation epoch:4 auc:0.8113315873174746 precision:0.8044895003620565 recall:0.8988673139158576
# Validation loss : 0.4881039758523305
# Done for epoch 5
# 0.5474335408511282
# Validation epoch:5 auc:0.8155006172221666 precision:0.8011569052783803 recall:0.8964401294498382
# Validation loss : 0.4788308666463484
# Done for epoch 6
# 0.539634671907465
# Validation epoch:6 auc:0.817245242940869 precision:0.8039358600583091 recall:0.8923948220064725
# Validation loss : 0.47395748841135127
# Done for epoch 7
# 0.5333296855708131
# Validation epoch:7 auc:0.8185714365150858 precision:0.8148984198645598 recall:0.8762135922330098
# Validation loss : 0.47702717467358235
# Done for epoch 8
# 0.5273457795631986
# Validation epoch:8 auc:0.818995429219631 precision:0.8197097020626433 recall:0.8681229773462783
# Validation loss : 0.4781733254591624
# Done for epoch 9
# 0.522438717489483
# Validation epoch:9 auc:0.8173717456822251 precision:0.8229407236335643 recall:0.8648867313915858
# Validation loss : 0.47902435221170125
# Done for epoch 10
# 0.5217053107604259
# Validation epoch:10 auc:0.8184352027936254 precision:0.8235294117647058 recall:0.86084142394822
# Validation loss : 0.47860997078711526
# Done for epoch 11
# 0.518428657736097
# Validation epoch:11 auc:0.8177832271266362 precision:0.8212634822804314 recall:0.8624595469255664
# Validation loss : 0.47683341304461163
# Testing epoch:11 auc:0.7834413789013966 precision:0.7908242612752722 recall:0.8288508557457213 F1:0.809391165937127
# Testing loss : 0.5181750879998792
# Done for epoch 0
# 0.7072521242774835
# Validation epoch:0 auc:0.7546583591899376 precision:0.7809457579972183 recall:0.9085760517799353
# Validation loss : 0.5317187842569853
# Done for epoch 1
# 0.5910374404502516
# Validation epoch:1 auc:0.7927315139180819 precision:0.7979724837074583 recall:0.8915857605177994
# Validation loss : 0.4997504750887553
# Done for epoch 2
# 0.5719093304722249
# Validation epoch:2 auc:0.8033897174123377 precision:0.8023340627279358 recall:0.889967637540453
# Validation loss : 0.49032869412187946
# Done for epoch 3
# 0.5606332043138873
# Validation epoch:3 auc:0.8113288070374447 precision:0.8050359712230216 recall:0.9053398058252428
# Validation loss : 0.4818009687097449
# Done for epoch 4
# 0.549560868564774
# Validation epoch:4 auc:0.8159120986665775 precision:0.8041756659467243 recall:0.9037216828478964
# Validation loss : 0.47530688005581234
# Done for epoch 5
# 0.5398278806139442
# Validation epoch:5 auc:0.8185505844148623 precision:0.8073859522085446 recall:0.9021035598705501
# Validation loss : 0.47259919998938577
# Done for epoch 6
# 0.5328911251130224
# Validation epoch:6 auc:0.8204689776354275 precision:0.8073859522085446 recall:0.9021035598705501
# Validation loss : 0.4710133211654529
# Done for epoch 7
# 0.5284551722662789
# Validation epoch:7 auc:0.8217103726687353 precision:0.8205904617713853 recall:0.8770226537216829
# Validation loss : 0.47245713179571586
# Done for epoch 8
# 0.5237369251852276
# Validation epoch:8 auc:0.8217812698094952 precision:0.8110294117647059 recall:0.8923948220064725
# Validation loss : 0.4695294525539666
# Done for epoch 9
# 0.5194866550820214
# Validation epoch:9 auc:0.8222087378640777 precision:0.8136599851521901 recall:0.8867313915857605
# Validation loss : 0.47042141671766313
# Done for epoch 10
# 0.5185990130700985
# Validation epoch:10 auc:0.8212849898241751 precision:0.8168054504163512 recall:0.8729773462783171
# Validation loss : 0.47298057560335127
# Done for epoch 11
# 0.5144519224888137
# Validation epoch:11 auc:0.8220871006127737 precision:0.8158490566037736 recall:0.8745954692556634
# Validation loss : 0.4710340494649452
# Testing epoch:11 auc:0.7905474262814811 precision:0.7879481311975591 recall:0.8418907905460473 F1:0.8140267927501971
# Testing loss : 0.5130919814109802
# Done for epoch 0
# 0.7071984843546603
# Validation epoch:0 auc:0.7903926033430086 precision:0.7972483707458363 recall:0.8907766990291263
# Validation loss : 0.5072302023569742
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-b93efaf3fff5> in <module>()
#       1 for num in range(20):
# ----> 2   model, loss = process()
#       3   loss = round(loss, 3) * 100
#       4   saving_path = '/content/drive/MyDrive/iirlab/topic/LSAN/LSANori/model_parameters/' + str(num) + '_' + str(loss) + '_models.pth'
#       5   torch.save(model.state_dict(), saving_path)
#
# <ipython-input-5-a1e9d7883eb8> in process()
#      31   for epoch in range(epochs):
#      32       model.train()
# ---> 33       LSAN_train.train(epoch)
#      34
#      35       # Validation
#
# /content/drive/MyDrive/iirlab/topic/LSAN/LSANori/trainer.py in train(self, epoch)
#      59             self.optim.zero_grad()
#      60             loss.backward()
# ---> 61             self.optim.step()
#      62
#      63             avg_loss = avg_loss + loss.item()
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/adam.py in step(self, closure)
#     108                     grads.append(p.grad)
#     109
# --> 110                     state = self.state[p]
#     111                     # Lazy state initialization
#     112                     if len(state) == 0:
#
# /usr/local/lib/python3.7/dist-packages/torch/_tensor.py in __hash__(self)
#     649
#     650     def __hash__(self):
# --> 651         if has_torch_function_unary(self):
#     652             return handle_torch_function(Tensor.__hash__, (self,), self)
#     653         return id(self)
#
# KeyboardInterrupt:

# %% [markdown]
# # 儲存模型

# %% [markdown]
# # 實驗5
# 將hidden attenhead layer同時調高

# %%
output_path = '/content/drive/MyDrive/iirlab/topic/LSAN/LSANori/output/result.txt'
hidden = 256 
layers = 8
attn_heads = 8 
dropout = 0.1
batch_size = 32
epochs = 200
num_workers = 2
with_cuda = 1
lr = 0.00005
adam_weight_decay = 0.01 ###
adam_beta1 = 0.9
adam_beta2 = 0.999
saving_path = '/content/drive/MyDrive/iirlab/topic/LSAN/LSANori/model_parameters/models.pth'

def process():
  # print("Creating Dataloader")
  train_data_loader = DataLoader(train_dataset, batch_size=batch_size, num_workers=num_workers, collate_fn=train_dataset.collate_fn,shuffle=False)
  validate_data_loader = DataLoader(validate_dataset, batch_size=batch_size, num_workers=num_workers, collate_fn=test_dataset.collate_fn,shuffle=False)
  test_data_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=num_workers, collate_fn=test_dataset.collate_fn,shuffle=False)




  embedding_dim = hidden
  code2idx_file = '/content/drive/MyDrive/iirlab/topic/LSAN/LSANori/code2idx_new.pickle'



  with open(code2idx_file, 'rb') as f:
      code2idx = pickle.load(f)
      #  list out keys and values separately
      diagnosis_code_list = list(code2idx.keys())
      dignosis_index_list = list(code2idx.values())
      # print(len(dignosis_index_list))

  # model = LSAN(len(dignosis_index_list), embedding_dim, transformer_hidden = hidden, attn_heads = attn_heads,
  #                     transformer_dropout = dropout, transformer_layers = layers)
  model = LSAN(51, embedding_dim, transformer_hidden = hidden, attn_heads = attn_heads,
                      transformer_dropout = dropout, transformer_layers = layers)

  # defining trainer
  LSAN_train = LSAN_trainer(model, train_dataloader=train_data_loader, validate_dataloader=validate_data_loader, test_dataloader=test_data_loader, with_cuda=with_cuda, lr=lr, output_dir=output_path)

  # training process
  for epoch in range(epochs):
      model.train()
      LSAN_train.train(epoch)
  
      # Validation
      if validate_data_loader is not None:
          model.eval()
          LSAN_train.validate(epoch)
        
  torch.save(model.state_dict(), saving_path)

  # Test after the end of training
  # test_model = LSAN(len(dignosis_index_list), embedding_dim, transformer_hidden = hidden, attn_heads = attn_heads, transformer_dropout = dropout, transformer_layers = layers) 
  test_model = LSAN(51, embedding_dim, transformer_hidden = hidden, attn_heads = attn_heads, transformer_dropout = dropout, transformer_layers = layers) 


  test_model.load_state_dict(torch.load(saving_path))
  test_model.eval()

  LSAN_test = LSAN_trainer(test_model, train_dataloader=train_data_loader, validate_dataloader=validate_data_loader, test_dataloader=test_data_loader, with_cuda=with_cuda, lr=lr, output_dir=output_path)

  LSAN_test.test(epoch)

# %%
hidden = 2048 
layers = 64
attn_heads = 64 
epochs = 100
process()

# %%
hidden = 2048 
layers = 64
attn_heads = 64 
epochs = 200
process()

# %%
hidden = 4096
layers = 64
attn_heads = 64 
epochs = 100
process()

# %%
hidden = 4096 
layers = 64
attn_heads = 64 
epochs = 200
process()

# %% [markdown]
# # 一次跑很多種

# %%
from itertools import product
parameters = dict(
    lr_value = [0.0005, 0.0001],
    batch_size_value = [32, 64],
    hidden_value = [128, 256, 512],
    #awd_value = [0.01, 0.005, 0.001],
    layers_value = [2, 4, 8],
)

param_values = [v for v in parameters.values()]

for lr_value, batch_size_value, hidden_value, layers_value in product(*param_values):
  lr = lr_value
  batch_size = batch_size_value
  hidden = hidden_value
  #adam_weight_decay = awd_value
  layers = layers_value
  comment = f' lr = {lr} batch_size = {batch_size} hidden = {hidden} layers = {layers}'
  print(comment)
  process()
# Out:
#  lr = 0.0005 batch_size = 32 hidden = 128 layers = 2
# Testing epoch:19 auc:0.7757754527640222 precision:0.827996340347667 recall:0.7375713121434393 F1:0.7801724137931034
#  lr = 0.0005 batch_size = 32 hidden = 128 layers = 4
# Testing epoch:19 auc:0.7830828358548563 precision:0.8160919540229885 recall:0.752241238793806 F1:0.7828668363019509
#  lr = 0.0005 batch_size = 32 hidden = 128 layers = 8
# Testing epoch:19 auc:0.772555460403747 precision:0.8151875571820677 recall:0.726161369193154 F1:0.7681034482758621
#  lr = 0.0005 batch_size = 32 hidden = 256 layers = 2
# Testing epoch:19 auc:0.7773268409461676 precision:0.8090366581415175 recall:0.7734311328443357 F1:0.7908333333333334
#  lr = 0.0005 batch_size = 32 hidden = 256 layers = 4
# Testing epoch:19 auc:0.7764952968805376 precision:0.8031173092698933 recall:0.797881010594947 F1:0.8004905968928863
#  lr = 0.0005 batch_size = 32 hidden = 256 layers = 8
# Testing epoch:19 auc:0.7771324002940053 precision:0.82277318640955 recall:0.7302363488182559 F1:0.773747841105354
#  lr = 0.0005 batch_size = 32 hidden = 512 layers = 2
# Testing epoch:19 auc:0.7566154639615973 precision:0.8686030428769018 recall:0.5118174409127955 F1:0.6441025641025642
#  lr = 0.0005 batch_size = 32 hidden = 512 layers = 4
# Testing epoch:19 auc:0.7821216646877849 precision:0.8072390572390572 recall:0.7815810920945395 F1:0.7942028985507247
#  lr = 0.0005 batch_size = 32 hidden = 512 layers = 8
# Testing epoch:19 auc:0.5 precision:0.6749174917491749 recall:1.0 F1:0.8059113300492611
#  lr = 0.0005 batch_size = 64 hidden = 128 layers = 2
# Testing epoch:19 auc:0.7710909499598018 precision:0.7810831426392068 recall:0.8345558272208639 F1:0.8069345941686367
#  lr = 0.0005 batch_size = 64 hidden = 128 layers = 4
# Testing epoch:19 auc:0.7738696585704888 precision:0.7781087118391661 recall:0.8516707416462918 F1:0.8132295719844359
#  lr = 0.0005 batch_size = 64 hidden = 128 layers = 8
# Testing epoch:19 auc:0.7795567028933046 precision:0.7707715133531158 recall:0.8467807660961695 F1:0.8069902912621358
#  lr = 0.0005 batch_size = 64 hidden = 256 layers = 2
# Testing epoch:19 auc:0.7805040839432013 precision:0.7874806800618238 recall:0.830480847595762 F1:0.8084093613645379
#  lr = 0.0005 batch_size = 64 hidden = 256 layers = 4
# Testing epoch:19 auc:0.7812997737041772 precision:0.7970660146699267 recall:0.7970660146699267 F1:0.7970660146699268
#  lr = 0.0005 batch_size = 64 hidden = 256 layers = 8
# Testing epoch:19 auc:0.7610407125629347 precision:0.7940935192780968 recall:0.7889160554197229 F1:0.7914963205233033
#  lr = 0.0005 batch_size = 64 hidden = 512 layers = 2
# Testing epoch:19 auc:0.7379670885063511 precision:0.7600291757840992 recall:0.8492257538712307 F1:0.8021555042340262
#  lr = 0.0005 batch_size = 64 hidden = 512 layers = 4
# Testing epoch:19 auc:0.7660037757340824 precision:0.8212290502793296 recall:0.7188264058679706 F1:0.7666232073011735
#  lr = 0.0005 batch_size = 64 hidden = 512 layers = 8
# Testing epoch:19 auc:0.7832303901086247 precision:0.830101569713758 recall:0.732681336593317 F1:0.7783549783549784
#  lr = 0.0001 batch_size = 32 hidden = 128 layers = 2
# Testing epoch:19 auc:0.7817479525123524 precision:0.8123370981754996 recall:0.7620211898940505 F1:0.7863751051303617
#  lr = 0.0001 batch_size = 32 hidden = 128 layers = 4
# Testing epoch:19 auc:0.7873963845070792 precision:0.8080808080808081 recall:0.78239608801956 F1:0.7950310559006212
#  lr = 0.0001 batch_size = 32 hidden = 128 layers = 8
# Testing epoch:19 auc:0.7804447864393504 precision:0.7962662337662337 recall:0.7995110024449877 F1:0.7978853192354616
#  lr = 0.0001 batch_size = 32 hidden = 256 layers = 2
# Testing epoch:19 auc:0.7732256600984339 precision:0.8132474701011959 recall:0.7204563977180114 F1:0.7640449438202248
#  lr = 0.0001 batch_size = 32 hidden = 256 layers = 4
# Testing epoch:19 auc:0.7836565047293207 precision:0.7996715927750411 recall:0.7938060309698451 F1:0.7967280163599182
#  lr = 0.0001 batch_size = 32 hidden = 256 layers = 8
# Testing epoch:19 auc:0.7847776412556178 precision:0.8196428571428571 recall:0.7481662591687042 F1:0.7822752449936089
#  lr = 0.0001 batch_size = 32 hidden = 512 layers = 2
# Testing epoch:19 auc:0.7679550773142919 precision:0.8375241779497099 recall:0.7057864710676447 F1:0.7660327288810262
#  lr = 0.0001 batch_size = 32 hidden = 512 layers = 4
# Testing epoch:19 auc:0.7731704996297354 precision:0.8024691358024691 recall:0.7946210268948656 F1:0.7985257985257984
#  lr = 0.0001 batch_size = 32 hidden = 512 layers = 8
# Testing epoch:19 auc:0.7742888781325976 precision:0.8088360237892949 recall:0.7758761206193969 F1:0.7920133111480865
#  lr = 0.0001 batch_size = 64 hidden = 128 layers = 2
# Testing epoch:19 auc:0.7639849025797172 precision:0.7697320782041999 recall:0.8663406682966586 F1:0.8151840490797546
#  lr = 0.0001 batch_size = 64 hidden = 128 layers = 4
# Testing epoch:19 auc:0.7745770915815473 precision:0.7761868877166541 recall:0.8394458027709861 F1:0.8065779169929522
#  lr = 0.0001 batch_size = 64 hidden = 128 layers = 8
# Testing epoch:19 auc:0.7586743284557689 precision:0.7718631178707225 recall:0.8272208638956805 F1:0.7985837922895357
#  lr = 0.0001 batch_size = 64 hidden = 256 layers = 2
# Testing epoch:19 auc:0.7727829973371283 precision:0.770941438102298 recall:0.8475957620211899 F1:0.8074534161490683
#  lr = 0.0001 batch_size = 64 hidden = 256 layers = 4
# Testing epoch:19 auc:0.7774440569421518 precision:0.7770320656226697 recall:0.8492257538712307 F1:0.8115264797507789
#  lr = 0.0001 batch_size = 64 hidden = 256 layers = 8
# Testing epoch:19 auc:0.7857401914344067 precision:0.7878554957724827 recall:0.8353708231458843 F1:0.8109177215189872
#  lr = 0.0001 batch_size = 64 hidden = 512 layers = 2
# Testing epoch:19 auc:0.7791057660616941 precision:0.8065054211843202 recall:0.7881010594947025 F1:0.79719703215169
#  lr = 0.0001 batch_size = 64 hidden = 512 layers = 4
# Testing epoch:19 auc:0.7753079677918022 precision:0.7938808373590982 recall:0.8035859820700897 F1:0.7987039287160793
#  lr = 0.0001 batch_size = 64 hidden = 512 layers = 8
# Testing epoch:19 auc:0.7775047334577202 precision:0.7878548895899053 recall:0.8141809290953546 F1:0.8008016032064128

# %%
from itertools import product
parameters = dict(
    lr_value = [0.0005, 0.0001],
    batch_size_value = [32, 64],
    hidden_value = [128, 256, 512],
    #awd_value = [0.01, 0.005, 0.001],
    layers_value = [2, 4, 8],
)

param_values = [v for v in parameters.values()]

for lr_value, batch_size_value, hidden_value, layers_value in product(*param_values):
  lr = lr_value
  batch_size = batch_size_value
  hidden = hidden_value
  #adam_weight_decay = awd_value
  layers = layers_value
  comment = f' lr = {lr} batch_size = {batch_size} hidden = {hidden} layers = {layers}'
  print(comment)
  process()
# Out:
#  lr = 0.0005 batch_size = 32 hidden = 128 layers = 2
# Testing epoch:19 auc:0.7807040406422333 precision:0.8879456706281834 recall:0.4262428687856561 F1:0.5759911894273128
#  lr = 0.0005 batch_size = 32 hidden = 128 layers = 4
# Testing epoch:19 auc:0.7782549158320198 precision:0.8927973199329984 recall:0.4343928280358598 F1:0.5844298245614036
#  lr = 0.0005 batch_size = 32 hidden = 128 layers = 8
# Testing epoch:19 auc:0.7870240513433644 precision:0.9034267912772586 recall:0.47269763651181745 F1:0.6206527554842162
#  lr = 0.0005 batch_size = 32 hidden = 256 layers = 2
# Testing epoch:19 auc:0.7820913264300007 precision:0.8978930307941653 recall:0.4515077424612877 F1:0.6008676789587853
#  lr = 0.0005 batch_size = 32 hidden = 256 layers = 4
# Testing epoch:19 auc:0.7871178241401517 precision:0.8956521739130435 recall:0.5036674816625917 F1:0.6447574334898278
#  lr = 0.0005 batch_size = 32 hidden = 256 layers = 8
# Testing epoch:19 auc:0.7657059092031105 precision:0.8757861635220126 recall:0.4539527302363488 F1:0.5979602791196993
#  lr = 0.0005 batch_size = 32 hidden = 512 layers = 2
# Testing epoch:19 auc:0.7702731960113465 precision:0.8823529411764706 recall:0.4889975550122249 F1:0.6292606187729418
#  lr = 0.0005 batch_size = 32 hidden = 512 layers = 4
# Testing epoch:19 auc:0.7799248990218669 precision:0.9008695652173913 recall:0.4221678891605542 F1:0.5749167591564928
#  lr = 0.0005 batch_size = 32 hidden = 512 layers = 8
# Testing epoch:19 auc:0.7697808888282123 precision:0.8814352574102964 recall:0.46047269763651183 F1:0.6049250535331905
#  lr = 0.0005 batch_size = 64 hidden = 128 layers = 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-80c57200bd1d> in <module>()
#      18   comment = f' lr = {lr} batch_size = {batch_size} hidden = {hidden} layers = {layers}'
#      19   print(comment)
# ---> 20   process()
#
# <ipython-input-5-65fb6401c3d3> in process()
#      31   for epoch in range(epochs):
#      32       model.train()
# ---> 33       LSAN_train.train(epoch)
#      34
#      35       # Validation
#
# /content/drive/MyDrive/iirlab/topic/LSAN/LSANori/trainer.py in train(self, epoch)
#      59             self.optim.zero_grad()
#      60             loss.backward()
# ---> 61             self.optim.step()
#      62
#      63             avg_loss = avg_loss + loss.item()
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      86                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      87                 with torch.autograd.profiler.record_function(profile_name):
# ---> 88                     return func(*args, **kwargs)
#      89             return wrapper
#      90
#
# /usr/local/lib/python3.7/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/adam.py in step(self, closure)
#     142                    lr=group['lr'],
#     143                    weight_decay=group['weight_decay'],
# --> 144                    eps=group['eps'])
#     145         return loss
#
# /usr/local/lib/python3.7/dist-packages/torch/optim/_functional.py in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, amsgrad, beta1, beta2, lr, weight_decay, eps)
#      85         # Decay the first and second moment running average coefficient
#      86         exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
# ---> 87         exp_avg_sq.mul_(beta2).addcmul_(grad, grad.conj(), value=1 - beta2)
#      88         if amsgrad:
#      89             # Maintains the maximum of all 2nd moment running avg. till now
#
# KeyboardInterrupt:
